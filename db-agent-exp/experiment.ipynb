# %%
import streamlit as st
import pandas as pd
import json
from bedrock_df_agent import DataFrameMetadataVectorRetriever, FileAgent
from PIL import Image
from typing import Dict
from io import BytesIO
from dotenv import load_dotenv
from pathlib import Path
from langchain_community.cache import SQLiteCache
from langchain.globals import set_llm_cache

# %%
def load_table_data(selected_tables):
    data_config = []
    for table_path_name in selected_tables:
        df = pd.read_parquet(f"data/processed_data/{table_path_name}.parquet")
        with open(f"data/processed_data/{table_path_name}_metadata.json") as f:
            df_metadata = json.load(f)
            print(f"df_metadata:{df_metadata}")
        data_config.append((df, df_metadata))
    table_retriever = DataFrameMetadataVectorRetriever(data_config)
    return data_config, table_retriever

# %%
output = load_table_data(["outdoor_lighting_products"])
# Out:
# df_metadata:{'name': 'Outdoor_Lighting_Products', 'description': 'This table contains information about various outdoor lighting products from different retailers, including product details, specifications, and sales performance.', 'columns': [{'name': 'Retailer', 'data_type': 'string', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': False, 'is_numeric': False, 'is_categorical': True, 'is_datetime': False, 'datetime_format': None, 'description': 'The name of the retailer selling the product'}, {'name': 'Product Name', 'data_type': 'string', 'primary_key': False, 'foreign_key': False, 'unique': True, 'nullable': False, 'is_numeric': False, 'is_categorical': False, 'is_datetime': False, 'datetime_format': None, 'description': 'The full name or title of the lighting product'}, {'name': 'Product URL', 'data_type': 'string', 'primary_key': True, 'foreign_key': False, 'unique': True, 'nullable': False, 'is_numeric': False, 'is_categorical': False, 'is_datetime': False, 'datetime_format': None, 'description': 'The unique URL link to the product page'}, {'name': 'Brand', 'data_type': 'string', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': False, 'is_numeric': False, 'is_categorical': True, 'is_datetime': False, 'datetime_format': None, 'description': 'The brand name of the lighting product'}, {'name': 'Rank', 'data_type': 'string', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': False, 'is_numeric': False, 'is_categorical': True, 'is_datetime': False, 'datetime_format': None, 'description': 'The sales rank category of the product (e.g., Good Seller, Average Seller, Poor Seller)'}, {'name': 'Top Seller', 'data_type': 'boolean', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': True, 'is_numeric': False, 'is_categorical': True, 'is_datetime': False, 'datetime_format': None, 'description': 'Indicates whether the product is a top seller (Yes/No)'}, {'name': 'Power Source', 'data_type': 'string', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': False, 'is_numeric': False, 'is_categorical': True, 'is_datetime': False, 'datetime_format': None, 'description': 'The type of power source for the lighting product (e.g., hardwired, battery powered, solar powered, plug-in)'}, {'name': 'Type', 'data_type': 'string', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': False, 'is_numeric': False, 'is_categorical': True, 'is_datetime': False, 'datetime_format': None, 'description': 'The category or type of lighting product (e.g., Spot & Flood Lights, String Lights, Path Lights)'}, {'name': 'Color Changing', 'data_type': 'boolean', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': False, 'is_numeric': False, 'is_categorical': True, 'is_datetime': False, 'datetime_format': None, 'description': 'Indicates whether the product has color-changing capabilities (True/False)'}, {'name': 'brightness (lumens)', 'data_type': 'float', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': True, 'is_numeric': True, 'is_categorical': False, 'is_datetime': False, 'datetime_format': None, 'description': 'The brightness of the lighting product measured in lumens'}, {'name': 'brightness (lumens) Bucket', 'data_type': 'string', 'primary_key': False, 'foreign_key': False, 'unique': False, 'nullable': True, 'is_numeric': False, 'is_categorical': True, 'is_datetime': False, 'datetime_format': None, 'description': 'A categorical range of brightness levels for the lighting product'}]}

# %%
output[0]
# Out:
# [(     Retailer                                       Product Name  \
#   0     Menards  Enchanted Garden 6.3" Glass Flameless Candle L...
#   1     Menards  Enchanted Garden 14" Metal & Glass Solar LED L...
#   2     Menards  Enchanted Garden 19.5" Blue Ceramic Solar Lantern
#   3     Menards  Enchanted Garden 10-5/8" Metal Solar Green Han...
#   4     Menards  Enchanted Garden 12" Bamboo Solar LED Lantern ...
#   ...       ...                                                ...
#   1332   Lowe's  Harbor Breeze 30-Lumen Grey Solar LED Flood Light
#   1333   Lowe's  Harbor Breeze 3-Lumen Black Solar Integrated L...
#   1334   Lowe's  Harbor Breeze White Incandescent Edison String...
#   1335   Lowe's  Feit Electric Landscape LED 35-Watt EQ MR16 Br...
#   1336   Lowe's  Enbrighten Outdoor 24-ft Integrated LED Multic...
#
#                                               Product URL             Brand  \
#   0     https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#   1     https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#   2     https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#   3     https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#   4     https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#   ...                                                 ...               ...
#   1332  https://www.lowes.com/pd/Portfolio-30-Lumen-Gr...     Harbor Breeze
#   1333  https://www.lowes.com/pd/Portfolio-3LM-Crackle...     Harbor Breeze
#   1334  https://www.lowes.com/pd/Portfolio-White-Incan...     Harbor Breeze
#   1335  https://www.lowes.com/pd/Feit-Electric-35-Watt...     Feit Electric
#   1336  https://www.lowes.com/pd/Enbrighten-Flex-Light...        Enbrighten
#
#                Rank Top Seller     Power Source                   Type  \
#   0     Poor Seller       None  battery powered               Lanterns
#   1     Good Seller        Yes    solar powered               Lanterns
#   2     Good Seller        Yes    solar powered               Lanterns
#   3     Poor Seller       None    solar powered               Lanterns
#   4     Good Seller        Yes    solar powered               Lanterns
#   ...           ...        ...              ...                    ...
#   1332  Poor Seller       None    solar powered    Spot & Flood Lights
#   1333  Best Seller        Yes    solar powered            Path Lights
#   1334  Poor Seller       None             None  Parts and Accessories
#   1335  Poor Seller       None          plug-in                   None
#   1336  Poor Seller       None          plug-in          String Lights
#
#         Color Changing  brightness (lumens) brightness (lumens) Bucket
#   0              False                  NaN                       None
#   1              False                  NaN                       None
#   2              False                  NaN                       None
#   3              False                  NaN                       None
#   4              False                  NaN                       None
#   ...              ...                  ...                        ...
#   1332           False                 30.0                       0-32
#   1333           False                  3.0                       0-32
#   1334           False                  NaN                       None
#   1335           False                340.0                    264-450
#   1336            True                  NaN                       None
#
#   [1337 rows x 11 columns],
#   {'name': 'Outdoor_Lighting_Products',
#    'description': 'This table contains information about various outdoor lighting products from different retailers, including product details, specifications, and sales performance.',
#    'columns': [{'name': 'Retailer',
#      'data_type': 'string',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': False,
#      'is_numeric': False,
#      'is_categorical': True,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'The name of the retailer selling the product'},
#     {'name': 'Product Name',
#      'data_type': 'string',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': True,
#      'nullable': False,
#      'is_numeric': False,
#      'is_categorical': False,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'The full name or title of the lighting product'},
#     {'name': 'Product URL',
#      'data_type': 'string',
#      'primary_key': True,
#      'foreign_key': False,
#      'unique': True,
#      'nullable': False,
#      'is_numeric': False,
#      'is_categorical': False,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'The unique URL link to the product page'},
#     {'name': 'Brand',
#      'data_type': 'string',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': False,
#      'is_numeric': False,
#      'is_categorical': True,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'The brand name of the lighting product'},
#     {'name': 'Rank',
#      'data_type': 'string',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': False,
#      'is_numeric': False,
#      'is_categorical': True,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'The sales rank category of the product (e.g., Good Seller, Average Seller, Poor Seller)'},
#     {'name': 'Top Seller',
#      'data_type': 'boolean',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': True,
#      'is_numeric': False,
#      'is_categorical': True,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'Indicates whether the product is a top seller (Yes/No)'},
#     {'name': 'Power Source',
#      'data_type': 'string',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': False,
#      'is_numeric': False,
#      'is_categorical': True,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'The type of power source for the lighting product (e.g., hardwired, battery powered, solar powered, plug-in)'},
#     {'name': 'Type',
#      'data_type': 'string',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': False,
#      'is_numeric': False,
#      'is_categorical': True,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'The category or type of lighting product (e.g., Spot & Flood Lights, String Lights, Path Lights)'},
#     {'name': 'Color Changing',
#      'data_type': 'boolean',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': False,
#      'is_numeric': False,
#      'is_categorical': True,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'Indicates whether the product has color-changing capabilities (True/False)'},
#     {'name': 'brightness (lumens)',
#      'data_type': 'float',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': True,
#      'is_numeric': True,
#      'is_categorical': False,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'The brightness of the lighting product measured in lumens'},
#     {'name': 'brightness (lumens) Bucket',
#      'data_type': 'string',
#      'primary_key': False,
#      'foreign_key': False,
#      'unique': False,
#      'nullable': True,
#      'is_numeric': False,
#      'is_categorical': True,
#      'is_datetime': False,
#      'datetime_format': None,
#      'description': 'A categorical range of brightness levels for the lighting product'}]})]

# %%
import pandas as pd

df = pd.read_csv("temp_plot_df.csv")

# %%
df = pd.read_parquet("data/processed_data/outdoor_lighting_products.parquet")

# %%
df.head()
# Out:
#   Retailer                                       Product Name  \
# 0  Menards  Enchanted Garden 6.3" Glass Flameless Candle L...
# 1  Menards  Enchanted Garden 14" Metal & Glass Solar LED L...
# 2  Menards  Enchanted Garden 19.5" Blue Ceramic Solar Lantern
# 3  Menards  Enchanted Garden 10-5/8" Metal Solar Green Han...
# 4  Menards  Enchanted Garden 12" Bamboo Solar LED Lantern ...
#
#                                          Product URL             Brand  \
# 0  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 1  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 2  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 3  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 4  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#
#           Rank Top Seller     Power Source      Type  Color Changing  \
# 0  Poor Seller       None  battery powered  Lanterns           False
# 1  Good Seller        Yes    solar powered  Lanterns           False
# 2  Good Seller        Yes    solar powered  Lanterns           False
# 3  Poor Seller       None    solar powered  Lanterns           False
# 4  Good Seller        Yes    solar powered  Lanterns           False
#
#    brightness (lumens) brightness (lumens) Bucket
# 0                  NaN                       None
# 1                  NaN                       None
# 2                  NaN                       None
# 3                  NaN                       None
# 4                  NaN                       None

# %%
df

# %%
df.value_counts()
# Out:
# Retailer    Product Name                                                                                                    Product URL                                                                                                                                                                             Brand          Rank         Top Seller  Power Source   Type                    Color Changing  brightness (lumens)  brightness (lumens) Bucket
# Home Depot  10-Light 10 ft. Outdoor/Indoor Plug-In Round Globe Bulb LED Rattan String Light                                 https://www.homedepot.com/p/Hampton-Bay-10-Light-10-ft-Outdoor-Indoor-Plug-In-Round-Globe-Bulb-LED-Rattan-String-Light-SL9522/317458630                                                 HAMPTON BAY    Good Seller  Yes         plug-in        String Lights           False           20.0                 0-32                          1
# Lowe's      Litex LED Outdoor Step and Stair light                                                                          https://www.lowes.com/pd/Litex-2-Pack-Black-Solar-Powered-LED-Deck-Lights/3265257                                                                                                       Litex          Good Seller  Yes         solar powered  Deck & Post Cap Lights  False           1.2                  0-32                          1
#             Philips Hue Calla Outdoor Extension 640-Lumen 8-Watt Black Low Voltage Plug-in Smart LED Outdoor Path Light     https://www.lowes.com/pd/Philips-Hue-Calla-Outdoor-Light-Extension/5005451961?idProductFound=false&idExtracted=true                                                                     Philips        Good Seller  Yes         plug-in        Path Lights             True            640.0                450-1280                      1
#             Portfolio 1.3-in Accent Lamp LED Light                                                                          https://www.lowes.com/pd/Portfolio-QD11P-F20C-WH-1/5001836309?idProductFound=false&idExtracted=true                                                                                     Portfolio      Good Seller  Yes         solar powered  Accent light            False           10.0                 0-32                          1
#             Portfolio 15-Lumen Black Solar LED Flood Light                                                                  https://www.lowes.com/pd/Portfolio-15-Lumen-Black-Solar-LED-Landscape-Flood-Light/999996016?idProductFound=false&idExtracted=true                                                       Portfolio      Good Seller  Yes         solar powered  Spot & Flood Lights     False           15.0                 0-32                          1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ..
#             Harbor Breeze 130-Lumen 5-Watt Bronze Low Voltage LED Outdoor Path Light (3000 K)                               https://www.lowes.com/pd/Harbor-Breeze-130-Lumen-5-Watt-Bronze-Low-Voltage-LED-Outdoor-Path-Light-3000-K/5012960653                                                                     Harbor Breeze  Best Seller  Yes         Hardwired      Path Lights             False           130.0                100-160                       1
#             Harbor Breeze 15-Lumen Black Solar LED Outdoor Path Light Kit (3500 K)                                          https://www.lowes.com/pd/Portfolio-RM20Ma-F15C-BK-2/5001836189?idProductFound=false&idExtracted=true                                                                                    Harbor Breeze  Good Seller  Yes         solar powered  Path Lights             False           15.0                 0-32                          1
#             Harbor Breeze 150-Lumen 4-Watt Bronze Low Voltage Hardwired LED Outdoor Path Light with Motion Sensor (3500 K)  https://www.lowes.com/pd/Harbor-Breeze-150-Lumen-4-Watt-Bronze-Low-Voltage-Hardwired-LED-Outdoor-Path-Light-with-Motion-Sensor-3500-K/5013317029?idProductFound=false&idExtracted=true  Harbor Breeze  Best Seller  Yes         hardwired      Path Lights             False           150.0                100-160                       1
#             Harbor Breeze 195-Lumen 6.5-Watt Black Low Voltage LED Flood Light                                              https://www.lowes.com/pd/Harbor-Breeze-6-5-Watt-Black-Low-Voltage-LED-Flood-Light/5012963109?idProductFound=false&idExtracted=true                                                      Harbor Breeze  Best Seller  Yes         Hardwired      Spot & Flood Lights     False           60.0                 32-100                        1
# Walmart     Mainstays Solar Powered Stainless Steel LED Landscape Disc Lights, 12 Lumens (4 Count)                          https://www.walmart.com/ip/Mainstays-Solar-Powered-Stainless-Steel-LED-Landscape-Walkway-Disc-Lights-12-Lumens-4-Count/197484953?athbdg=L1600                                           Mainstays      Good Seller  Yes         solar powered  Accent light            False           12.0                 0-32                          1
# Name: count, Length: 260, dtype: int64

# %%
df.values
# Out:
# array([['Menards',
#         'Enchanted Garden 6.3" Glass Flameless Candle LED Lantern - Assorted Styles',
#         'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-6-3-glass-flameless-candle-led-lantern-assorted-styles/sl57004/p-1564727284127-c-14310.htm',
#         ..., False, nan, None],
#        ['Menards',
#         'Enchanted Garden 14" Metal & Glass Solar LED Lantern - Assorted Colors',
#         'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-14-metal-glass-solar-led-lantern-assorted-colors/13358/p-1499754734947-c-14310.htm',
#         ..., False, nan, None],
#        ['Menards', 'Enchanted Garden 19.5" Blue Ceramic Solar Lantern',
#         'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-19-5-blue-ceramic-solar-lantern/si-ld2145/p-60892412417-c-14310.htm',
#         ..., False, nan, None],
#        ...,
#        ["Lowe's",
#         'Harbor Breeze White Incandescent Edison String Light Bulbs',
#         'https://www.lowes.com/pd/Portfolio-White-Incandescent-Edison-String-Light-Bulbs/50342110?idProductFound=false&idExtracted=true',
#         ..., False, nan, None],
#        ["Lowe's",
#         'Feit Electric Landscape LED 35-Watt EQ MR16 Bright White G5.3 Base LED Light Bulb',
#         'https://www.lowes.com/pd/Feit-Electric-35-Watt-Equivalent-MR16-Enhance-Reflector-LED/5005482835?idProductFound=false&idExtracted=true',
#         ..., False, 340.0, '264-450'],
#        ["Lowe's",
#         'Enbrighten Outdoor 24-ft Integrated LED Multicolor Rope Light',
#         'https://www.lowes.com/pd/Enbrighten-Flex-Light-Neon-High-Voltage-RGB-24-ft/5000859593?idProductFound=false&idExtracted=true',
#         ..., True, nan, None]], dtype=object)

# %%
unique_values = {}

for col in df.columns:
    unique_vals = df[col].unique()
    if len(unique_vals) < 10:
        unique_values[col] = unique_vals.tolist()
    else:
        unique_values[col] = f"{unique_vals.tolist()[:10]} there are more values here"

# %%
unique_values
# Out:
# {'Retailer': ['Menards', 'Home Depot', 'Walmart', "Lowe's"],
#  'Product Name': '[\'Enchanted Garden 6.3" Glass Flameless Candle LED Lantern - Assorted Styles\', \'Enchanted Garden 14" Metal & Glass Solar LED Lantern - Assorted Colors\', \'Enchanted Garden 19.5" Blue Ceramic Solar Lantern\', \'Enchanted Garden 10-5/8" Metal Solar Green Hanging Lantern\', \'Enchanted Garden 12" Bamboo Solar LED Lantern - Assorted Colors\', \'Enchanted Garden 8-3/4" Plastic Flameless Candle LED Lantern - Assorted Styles\', \'Enchanted Garden 25" Bronze Metal Solar LED Tripod Lantern\', \'Enchanted Garden 29.5" Antique White Wooden LED Lantern\', \'Patriot Lighting Corbett Black Low Voltage LED Path Landscape Light\', \'Patriot Lighting Low Voltage LED Flood Landscape Light\'] there are more values here',
#  'Product URL': "['https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-6-3-glass-flameless-candle-led-lantern-assorted-styles/sl57004/p-1564727284127-c-14310.htm', 'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-14-metal-glass-solar-led-lantern-assorted-colors/13358/p-1499754734947-c-14310.htm', 'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-19-5-blue-ceramic-solar-lantern/si-ld2145/p-60892412417-c-14310.htm', 'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-reg-10-5-8-metal-solar-green-hanging-lantern/t0099/p-1642874295130106-c-14310.htm', 'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-12-bamboo-solar-led-lantern-assorted-colors/ad-13-0592-bcdf/p-1444450350308-c-14310.htm', 'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-8-3-4-plastic-flameless-candle-led-lantern-assorted-styles/sl50070/p-1564727284354-c-14310.htm', 'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-25-bronze-metal-solar-led-tripod-lantern/c82619/p-1642874264591813-c-14310.htm', 'https://www.menards.com/main/outdoors/outdoor-decor/outdoor-lanterns-torches/enchanted-garden-trade-29-5-antique-white-wooden-led-lantern/sl81352/p-2890455940801979-c-14310.htm', 'https://www.menards.com/main/lighting-ceiling-fans/outdoor-lighting/landscape-lighting/patriot-lighting-reg-corbett-black-low-voltage-led-path-landscape-light/lv21027/p-10834816301964030-c-7541.htm', 'https://www.menards.com/main/lighting-ceiling-fans/outdoor-lighting/landscape-lighting/patriot-lighting-reg-low-voltage-led-flood-landscape-light/lv21030/p-10834816301964504-c-7541.htm'] there are more values here",
#  'Brand': "['Enchanted Garden', 'Patriot Lighting', 'PATRIOT LIGHTING', 'Xtreme', 'BrightLux Lighting', 'Feit Electric', 'Merkury Innovations', 'Westek', 'Simple Living Solutions', 'Hype'] there are more values here",
#  'Rank': ['Poor Seller',
#   'Good Seller',
#   'Average Seller',
#   'Best Seller',
#   'Unranked'],
#  'Top Seller': [None, 'Yes'],
#  'Power Source': ['battery powered',
#   'solar powered',
#   None,
#   'Hardwired',
#   'plug-in',
#   'hardwired'],
#  'Type': "['Lanterns', 'Path Lights', 'Spot & Flood Lights', 'String Lights', 'Parts and Accessories', 'Well Light', 'Accent light', None, 'Outdoor light', 'Deck & Post Cap Lights'] there are more values here",
#  'Color Changing': [False, True],
#  'brightness (lumens)': '[nan, 55.0, 32.0, 35.0, 480.0, 25.0, 1.2, 450.0, 120.0, 160.0] there are more values here',
#  'brightness (lumens) Bucket': [None,
#   '32-100',
#   '450-1280',
#   '0-32',
#   '100-160',
#   '160-264',
#   '264-450',
#   '1280-7500']}
