# %%
from dotenv import load_dotenv
load_dotenv("../.env")
# Out:
# True

# %%
import pandas as pd
from pydantic.v1 import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate
from langchain_aws import ChatBedrock
from langchain_community.cache import SQLiteCache
from langchain.globals import set_llm_cache
import json

# %%
set_llm_cache(SQLiteCache(database_path="./temp_folder/llm_cache.sqlite.db"))

# %%
from rapidfuzz import fuzz

def find_matching_values(value, column, df):
    uniques = pd.Series(df[column].unique())
    uniques_scores = uniques.apply(lambda x: fuzz.partial_ratio(x.lower(), value.lower()))
    uniques_scores.index = uniques
    return uniques_scores.sort_values(ascending=False).head(5).index.to_list()

# %%
class Column(BaseModel):
    name: str = Field(description='name for the column')
    data_type: str = Field(description='python data type of the column')
    primary_key: bool = Field(description='whether the column can be a primary key')
    foreign_key: bool = Field(description='whether the column can be a foreign key')
    unique: bool = Field(description='whether the column is unique') ###
    nullable: bool = Field(description='whether the column is nullable')
    is_numeric: bool = Field(description='whether the column is numeric')
    is_categorical: bool = Field(description='whether the column is categorical')
    is_datetime: bool = Field(description='whether the column is a datetime')
    datetime_format: str| None = Field(description='format of the datetime in  strftime format')
    description: str = Field(description='description of the column, add all the unique values to this description also') # unique values in description


class TableResponse(BaseModel):
    name: str = Field(description='appropriate name for the table')
    description: str = Field(description='description of the table')
    columns: list[Column]

def get_df_metadata(df: pd.DataFrame):
    system_prompt = """
You will be given csv sample of data. Understand the data and give metadata about thable and columns in the format specified


return json with the structure provided"""

    user_prompt = """
    Table Sample CSV String
    >>>
    {table_csv_string}
    <<<

    Output of `df.describe()`
    >>>
    {describe_output}
    <<<

    Output of `df.nunique()`
    >>>
    {nunique_output}
    <<<
    
    Unique values for each column
    >>>
    {unique_column_values}

    <<<
    
    """
    unique_values = {}

    for col in df.columns:
        unique_vals = df[col].unique()
        if len(unique_vals) < 10:
            unique_values[col] = unique_vals.tolist()
        else:
            unique_values[col] = f"{unique_vals.tolist()[:10]} there are more values here"

        prompt_template = ChatPromptTemplate.from_messages(
            [
                ("system", system_prompt),
                ("human", user_prompt),
            ]
        )

    chain = (
        prompt_template
        | ChatBedrock(
            model_id="anthropic.claude-3-5-sonnet-20240620-v1:0",
            model_kwargs=dict(temperature=0, max_tokens = 8000),

        ).with_structured_output(TableResponse)
    )


    return chain.invoke({"table_csv_string": df.sample(10, random_state=0).to_csv(index=False), "describe_output": df.describe().to_csv(), "nunique_output": df.nunique().to_csv(header=False),"unique_column_values":unique_values})

# %%
def process_datetime_columns(df, metadata: TableResponse):
    column_metadata_df = pd.DataFrame(metadata.dict()['columns'])
    df = df.copy()
    for _, row in column_metadata_df.iterrows():
        if row['is_datetime']:
            df[row['name']] = pd.to_datetime(df[row['name']], format=row['datetime_format'])
    return df

# %%
# df = pd.read_csv('./data/stylumia_all_data.csv')
# df = pd.read_parquet("data/processed_data/outdoor_lighting_products.parquet")
df = pd.read_parquet("data/processed_data/zip_code_data.parquet")

# %%
df.head()
# Out:
#   Retailer                                       Product Name  \
# 0        B  Enchanted Garden 6.3" Glass Flameless Candle L...
# 1        B  Enchanted Garden 14" Metal & Glass Solar LED L...
# 2        B  Enchanted Garden 19.5" Blue Ceramic Solar Lantern
# 3        B  Enchanted Garden 10-5/8" Metal Solar Green Han...
# 4        B  Enchanted Garden 12" Bamboo Solar LED Lantern ...
#
#                                          Product URL             Brand  \
# 0  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 1  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 2  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 3  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 4  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#
#           Rank Top Seller     Power Source      Type  Color Changing  \
# 0  Poor Seller       None  battery powered  Lanterns           False
# 1  Good Seller        Yes    solar powered  Lanterns           False
# 2  Good Seller        Yes    solar powered  Lanterns           False
# 3  Poor Seller       None    solar powered  Lanterns           False
# 4  Good Seller        Yes    solar powered  Lanterns           False
#
#    brightness (lumens) brightness (lumens) Bucket  in_store_availablity_48162  \
# 0                  NaN                       None                       False
# 1                  NaN                       None                        True
# 2                  NaN                       None                        True
# 3                  NaN                       None                       False
# 4                  NaN                       None                        True
#
#    in_store_availablity_63111  in_store_availablity_49418  \
# 0                        True                        True
# 1                        True                        True
# 2                        True                        True
# 3                       False                        True
# 4                        True                        True
#
#    Availabe_State_Michigan  Availabe_State_Missouri  Availabe_Region_Rural  \
# 0                     True                     True                  False
# 1                     True                     True                   True
# 2                     True                     True                   True
# 3                     True                    False                  False
# 4                     True                     True                   True
#
#    Availabe_Region_Urban  Availabe_Region_Coastal
# 0                   True                     True
# 1                   True                     True
# 2                   True                     True
# 3                  False                     True
# 4                   True                     True

# %%
# df["Retailer"].unique()

# %%
# retailer_psudo_name_dict = {"Lowe's":"A" , 'Menards':"B" , 'Home Depot':"C" , 'Walmart':"D"}

# %%
# df["Retailer"] = df["Retailer"].map(retailer_psudo_name_dict)
# df.head()

# %%
df["Retailer"].unique()
# Out:
# array(['B', 'C', 'D', 'A'], dtype=object)

# %%
# # generate metadata for every 30 columns, always include the first 5 columns
# metadatas = []
# for i in range(0, len(df.columns), 30):
#     print(f"{i} to {i+30}")
#     df_column_sample = df.iloc[:, i:i+30]
#     if i > 0:
#         df_column_sample = pd.concat([df.iloc[:, :5], df_column_sample], axis=1)
#     metadata = get_df_metadata(df_column_sample)
#     metadatas.append(metadata)

# %%
metadata = get_df_metadata(df)

# %%
metadata
# Out:
# TableResponse(name='Outdoor_Lighting_Products', description='This table contains information about various outdoor lighting products from different retailers, including product details, specifications, and availability.', columns=[Column(name='Retailer', data_type='string', primary_key=False, foreign_key=False, unique=False, nullable=False, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='The retailer selling the product. Unique values: A, B, C, D'), Column(name='Product Name', data_type='string', primary_key=False, foreign_key=False, unique=True, nullable=False, is_numeric=False, is_categorical=False, is_datetime=False, datetime_format=None, description='The name of the outdoor lighting product'), Column(name='Product URL', data_type='string', primary_key=True, foreign_key=False, unique=True, nullable=False, is_numeric=False, is_categorical=False, is_datetime=False, datetime_format=None, description='The URL of the product page'), Column(name='Brand', data_type='string', primary_key=False, foreign_key=False, unique=False, nullable=False, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='The brand of the product. Examples: Enchanted Garden, Patriot Lighting, Feit Electric, etc.'), Column(name='Rank', data_type='string', primary_key=False, foreign_key=False, unique=False, nullable=True, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='The sales rank of the product. Values: Poor Seller, Good Seller, Average Seller, Best Seller, Unranked'), Column(name='Top Seller', data_type='boolean', primary_key=False, foreign_key=False, unique=False, nullable=True, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='Indicates if the product is a top seller. Values: Yes, null'), Column(name='Power Source', data_type='string', primary_key=False, foreign_key=False, unique=False, nullable=True, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='The power source of the product. Values: battery powered, solar powered, hardwired, plug-in'), Column(name='Type', data_type='string', primary_key=False, foreign_key=False, unique=False, nullable=True, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='The type of outdoor lighting product. Examples: Lanterns, Path Lights, Spot & Flood Lights, String Lights, etc.'), Column(name='Color Changing', data_type='boolean', primary_key=False, foreign_key=False, unique=False, nullable=False, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='Indicates if the product has color-changing capabilities. Values: True, False'), Column(name='brightness (lumens)', data_type='float', primary_key=False, foreign_key=False, unique=False, nullable=True, is_numeric=True, is_categorical=False, is_datetime=False, datetime_format=None, description='The brightness of the product in lumens. Range: 0.0 to 7500.0'), Column(name='brightness (lumens) Bucket', data_type='string', primary_key=False, foreign_key=False, unique=False, nullable=True, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='Categorized brightness ranges. Values: 0-32, 32-100, 100-160, 160-264, 264-450, 450-1280, 1280-7500'), Column(name='in_store_availablity_48162', data_type='boolean', primary_key=False, foreign_key=False, unique=False, nullable=False, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='Indicates if the product is available in store 48162. Values: True, False'), Column(name='in_store_availablity_63111', data_type='boolean', primary_key=False, foreign_key=False, unique=False, nullable=False, is_numeric=False, is_categorical=True, is_datetime=False, datetime_format=None, description='Indicates if the product is available in store 63111. Values: True, False'), Column(name='in_stor ...

# %%
pd.DataFrame(metadata.dict()['columns'])
# Out:
#                           name data_type  primary_key  foreign_key  unique  \
# 0                     Retailer    string        False        False   False
# 1                 Product Name    string        False        False    True
# 2                  Product URL    string         True        False    True
# 3                        Brand    string        False        False   False
# 4                         Rank    string        False        False   False
# 5                   Top Seller   boolean        False        False   False
# 6                 Power Source    string        False        False   False
# 7                         Type    string        False        False   False
# 8               Color Changing   boolean        False        False   False
# 9          brightness (lumens)     float        False        False   False
# 10  brightness (lumens) Bucket    string        False        False   False
# 11  in_store_availablity_48162   boolean        False        False   False
# 12  in_store_availablity_63111   boolean        False        False   False
# 13  in_store_availablity_49418   boolean        False        False   False
# 14     Availabe_State_Michigan   boolean        False        False   False
# 15     Availabe_State_Missouri   boolean        False        False   False
# 16       Availabe_Region_Rural   boolean        False        False   False
# 17       Availabe_Region_Urban   boolean        False        False   False
# 18     Availabe_Region_Coastal   boolean        False        False   False
#
#     nullable  is_numeric  is_categorical  is_datetime datetime_format  \
# 0      False       False            True        False            None
# 1      False       False           False        False            None
# 2      False       False           False        False            None
# 3      False       False            True        False            None
# 4       True       False            True        False            None
# 5       True       False            True        False            None
# 6       True       False            True        False            None
# 7       True       False            True        False            None
# 8      False       False            True        False            None
# 9       True        True           False        False            None
# 10      True       False            True        False            None
# 11     False       False            True        False            None
# 12     False       False            True        False            None
# 13     False       False            True        False            None
# 14     False       False            True        False            None
# 15     False       False            True        False            None
# 16     False       False            True        False            None
# 17     False       False            True        False            None
# 18     False       False            True        False            None
#
#                                           description
# 0   The retailer selling the product. Unique value...
# 1            The name of the outdoor lighting product
# 2                         The URL of the product page
# 3   The brand of the product. Examples: Enchanted ...
# 4   The sales rank of the product. Values: Poor Se...
# 5   Indicates if the product is a top seller. Valu...
# 6   The power source of the product. Values: batte...
# 7   The type of outdoor lighting product. Examples...
# 8   Indicates if the product has color-changing ca...
# 9   The brightness of the product in lumens. Range...
# 10  Categorized brightness ranges. Values: 0-32, 3...
# 11  Indicates if the product is available in store...
# 12  Indicates if the product is available in store...
# 13  Indicates if the product is available in store...
# 14  Indicates if the product is available in Michi...
# 15  Indicates if the product is available in Misso...
# 16  Indicates if the product is available in rural...
# 17  Indicates if the product is available in urban...
# 18  Indicates if the product is available in coast...

# %%
metadata.name
# Out:
# 'Outdoor_Lighting_Products'

# %%
metadata.description
# Out:
# 'This table contains information about various outdoor lighting products from different retailers, including product details, specifications, and availability.'

# %%
df = process_datetime_columns(df, metadata)

# %%
df.head()
# Out:
#   Retailer                                       Product Name  \
# 0        B  Enchanted Garden 6.3" Glass Flameless Candle L...
# 1        B  Enchanted Garden 14" Metal & Glass Solar LED L...
# 2        B  Enchanted Garden 19.5" Blue Ceramic Solar Lantern
# 3        B  Enchanted Garden 10-5/8" Metal Solar Green Han...
# 4        B  Enchanted Garden 12" Bamboo Solar LED Lantern ...
#
#                                          Product URL             Brand  \
# 0  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 1  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 2  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 3  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 4  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#
#           Rank Top Seller     Power Source      Type  Color Changing  \
# 0  Poor Seller       None  battery powered  Lanterns           False
# 1  Good Seller        Yes    solar powered  Lanterns           False
# 2  Good Seller        Yes    solar powered  Lanterns           False
# 3  Poor Seller       None    solar powered  Lanterns           False
# 4  Good Seller        Yes    solar powered  Lanterns           False
#
#    brightness (lumens) brightness (lumens) Bucket  in_store_availablity_48162  \
# 0                  NaN                       None                       False
# 1                  NaN                       None                        True
# 2                  NaN                       None                        True
# 3                  NaN                       None                       False
# 4                  NaN                       None                        True
#
#    in_store_availablity_63111  in_store_availablity_49418  \
# 0                        True                        True
# 1                        True                        True
# 2                        True                        True
# 3                       False                        True
# 4                        True                        True
#
#    Availabe_State_Michigan  Availabe_State_Missouri  Availabe_Region_Rural  \
# 0                     True                     True                  False
# 1                     True                     True                   True
# 2                     True                     True                   True
# 3                     True                    False                  False
# 4                     True                     True                   True
#
#    Availabe_Region_Urban  Availabe_Region_Coastal
# 0                   True                     True
# 1                   True                     True
# 2                   True                     True
# 3                  False                     True
# 4                   True                     True

# %%
file_name = "outdoor_lighting_products_renamed_zipcode"

# %%
df.to_parquet(f"./data/processed_data/{file_name}.parquet", index=False)
with open(f"./data/processed_data/{file_name}_metadata.json", "w") as f:
    f.write(json.dumps(metadata.dict(), indent=4))

# %%
df = pd.read_parquet(f"./data/processed_data/{file_name}.parquet")

# %%
df.dtypes
# Out:
# Retailer                       object
# Product Name                   object
# Product URL                    object
# Brand                          object
# Rank                           object
# Top Seller                     object
# Power Source                   object
# Type                           object
# Color Changing                   bool
# brightness (lumens)           float64
# brightness (lumens) Bucket     object
# in_store_availablity_48162       bool
# in_store_availablity_63111       bool
# in_store_availablity_49418       bool
# Availabe_State_Michigan          bool
# Availabe_State_Missouri          bool
# Availabe_Region_Rural            bool
# Availabe_Region_Urban            bool
# Availabe_Region_Coastal          bool
# dtype: object

# %%
df.head()
# Out:
#   Retailer                                       Product Name  \
# 0        B  Enchanted Garden 6.3" Glass Flameless Candle L...
# 1        B  Enchanted Garden 14" Metal & Glass Solar LED L...
# 2        B  Enchanted Garden 19.5" Blue Ceramic Solar Lantern
# 3        B  Enchanted Garden 10-5/8" Metal Solar Green Han...
# 4        B  Enchanted Garden 12" Bamboo Solar LED Lantern ...
#
#                                          Product URL             Brand  \
# 0  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 1  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 2  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 3  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
# 4  https://www.menards.com/main/outdoors/outdoor-...  Enchanted Garden
#
#           Rank Top Seller     Power Source      Type  Color Changing  \
# 0  Poor Seller       None  battery powered  Lanterns           False
# 1  Good Seller        Yes    solar powered  Lanterns           False
# 2  Good Seller        Yes    solar powered  Lanterns           False
# 3  Poor Seller       None    solar powered  Lanterns           False
# 4  Good Seller        Yes    solar powered  Lanterns           False
#
#    brightness (lumens) brightness (lumens) Bucket  in_store_availablity_48162  \
# 0                  NaN                       None                       False
# 1                  NaN                       None                        True
# 2                  NaN                       None                        True
# 3                  NaN                       None                       False
# 4                  NaN                       None                        True
#
#    in_store_availablity_63111  in_store_availablity_49418  \
# 0                        True                        True
# 1                        True                        True
# 2                        True                        True
# 3                       False                        True
# 4                        True                        True
#
#    Availabe_State_Michigan  Availabe_State_Missouri  Availabe_Region_Rural  \
# 0                     True                     True                  False
# 1                     True                     True                   True
# 2                     True                     True                   True
# 3                     True                    False                  False
# 4                     True                     True                   True
#
#    Availabe_Region_Urban  Availabe_Region_Coastal
# 0                   True                     True
# 1                   True                     True
# 2                   True                     True
# 3                  False                     True
# 4                   True                     True
